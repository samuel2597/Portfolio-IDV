# %% [markdown]
# # Full-connected neural networks part 1 - Regression

# %% [markdown]
# For this assignment, you will use the [California Housing Dataset](https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html). You will perform a **linear regression** (with scikit-learn) to predict prices and then a **non-linear regression** with neural networks. Your goal is to improve the $R^2$-waarde of price predictions, in comparison to the regression-based baseline.
#
# Let's import the data first:

# %%
from sklearn import datasets

housing_df = datasets.fetch_california_housing(as_frame=True)

# Use the housing dataset features and targets
X = housing_df.data.drop(columns=['Latitude', 'Longitude'])
y = housing_df.target

# %% [markdown]
# You see that two features are latitude and longitude. We can't derive a linear relationship with house prices from these. A latitude of 20 degrees is not twice as import as a latitude of 10 degrees, or a longitude of 5 degrees does not contribute less than a house with a longitude of 10 degrees. Since linear relationships are meaningless here, we removed these columns from the dataset.

# %% [markdown]
# ### Exercise 1: Split the dataset into a training- and a testset

# %%
from sklearn.model_selection import

# Take 80% of the data as training data and 20% as testdata
# Use a seed (42) to guarantee reproducability
X_train, X_test, y_train, y_test =

# %% [markdown]
# ### Exercise 2: Look at the training data. Are there non-linear relations between some features and the target variable?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# JOUW CODE HIER

# %% [markdown]
# ### Exercise 3: Use scikit-learn to perform a linear regression on the data to predict prices. What is your $R^2$-score?

# %%
# JOUW CODE HIER

# %% [markdown]
# ### Exercise 4: Build a neural network in TensorFlow en Keras. Train in to predict house prices. The goal is to improve the RMSE- and $R^2$-scores of the linear model.

# %%
import tensorflow as tf
from tensorflow import keras

# %%
# JOUW CODE HIER

# %% [markdown]
# ### Exercise 5: Answer the following questions
#
# 1. What was your best $R^2$ with a linear regression model?
# 2. What was your best $R^2$ with a neural network?
# 3. How many hidden layers did you use for your best $R^2$ neural network? How many neurons per hidden layer? Which activation functions did you use?
# 4. For how many epochs did you train your network?
# 5. Draw the losscurve for training and validation. What do these tell you?

# %% [markdown]
# ```Your answers here```
